# %%
import findspark
findspark.init()
import pyspark
from random import random
from pyspark import SparkContext
import numpy as np
from math import sqrt

import matplotlib
import matplotlib.pyplot
import matplotlib.pyplot as plt
# %matplotlib inline 

from pyspark.mllib.linalg import Vectors

from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.linalg.distributed import RowMatrix

# %%
import os
port = 4040 + hash(os.getcwd().split("/")[2])%200
config = pyspark.SparkConf().set('spark.executor.memory', '512M')\
         .set('spark.cores.max', '1')\
         .set('spark.port.maxRetries','200')\
         .set('spark.ui.port', port)    
print port,     os.getcwd().split("/")[2]
# Out:
# 4182 zhl617

# %%
sc = pyspark.SparkContext(appName="Visualization", master='spark://polyp1:7077',conf = config )

# %% [markdown]
# # Data

# %%
rddData = sc.textFile("/scratch/ISE495/2018_midterm_data/recipes.txt")
# Each line of data represents a recipes, which is like:
# cusine;ID;ingredients1;ingredients2;...
print rddData.take(5)
print "We have:",rddData.count(), "recepies"
# Out:
# [u'greek;10259;romaine lettuce;black olives;grape tomatoes;garlic;pepper;purple onion;seasoning;garbanzo beans;feta cheese crumbles', u'southern_us;25693;plain flour;ground pepper;salt;tomatoes;ground black pepper;thyme;eggs;green tomatoes;yellow corn meal;milk;vegetable oil', u'filipino;20130;eggs;pepper;salt;mayonaise;cooking oil;green chilies;grilled chicken breasts;garlic powder;yellow onion;soy sauce;butter;chicken livers', u'indian;22213;water;vegetable oil;wheat;salt', u'indian;13162;black pepper;shallots;cornflour;cayenne pepper;onions;garlic paste;milk;butter;salt;lemon juice;water;chili powder;passata;oil;ground cumin;boneless chicken skinless thigh;garam masala;double cream;natural yogurt;bay leaf']
# We have: 39774 recepies

# %% [markdown]
# Create dictionarty to store index to each ingredient and represent each recipe as a sparse vector

# %%
d=[]
def qq(x):
    for i in x:
        for j in i.split(';')[2:]:
            if j not in d:
                d.append(j)
    return d
qq(rddData.collect())
dic={}
dicc = {}
def xx(x):
    for (num,value) in enumerate(x):
        dic[value] = num
        dicc[num] = value
    return len(dic)
xx(d)
# Out:
# 6714

# %%
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg.distributed import RowMatrix
features=[]

def SV(x):
    vals = []
    keys=[]
    for i in x.split(';')[2:]:
        for j in d:
            if i == j:
                keys.append(dic[i])
                vals.append(1)
    keys=list(set(keys))
    keys,vals=zip(*sorted(zip(keys,vals)))
    features = Vectors.sparse(6714,keys,vals)
    return features 
featuredata = rddData.map(SV)
featuredata.take(5)
# Out:
# [SparseVector(6714, {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0}),
#  SparseVector(6714, {9: 1.0, 10: 1.0, 11: 1.0, 12: 1.0, 13: 1.0, 14: 1.0, 15: 1.0, 16: 1.0, 17: 1.0, 18: 1.0, 19: 1.0}),
#  SparseVector(6714, {4: 1.0, 11: 1.0, 15: 1.0, 20: 1.0, 21: 1.0, 22: 1.0, 23: 1.0, 24: 1.0, 25: 1.0, 26: 1.0, 27: 1.0, 28: 1.0}),
#  SparseVector(6714, {11: 1.0, 19: 1.0, 29: 1.0, 30: 1.0}),
#  SparseVector(6714, {11: 1.0, 18: 1.0, 27: 1.0, 29: 1.0, 31: 1.0, 32: 1.0, 33: 1.0, 34: 1.0, 35: 1.0, 36: 1.0, 37: 1.0, 38: 1.0, 39: 1.0, 40: 1.0, 41: 1.0, 42: 1.0, 43: 1.0, 44: 1.0, 45: 1.0, 46: 1.0})]

# %% [markdown]
# Normalize each recipe

# %%
from pyspark.mllib.feature import Normalizer
from pyspark.mllib.util import MLUtils

normalizer = Normalizer(p=2)
data1 = normalizer.transform(featuredata)

print data1.take(5)
# Out:
# [SparseVector(6714, {0: 0.3333, 1: 0.3333, 2: 0.3333, 3: 0.3333, 4: 0.3333, 5: 0.3333, 6: 0.3333, 7: 0.3333, 8: 0.3333}), SparseVector(6714, {9: 0.3015, 10: 0.3015, 11: 0.3015, 12: 0.3015, 13: 0.3015, 14: 0.3015, 15: 0.3015, 16: 0.3015, 17: 0.3015, 18: 0.3015, 19: 0.3015}), SparseVector(6714, {4: 0.2887, 11: 0.2887, 15: 0.2887, 20: 0.2887, 21: 0.2887, 22: 0.2887, 23: 0.2887, 24: 0.2887, 25: 0.2887, 26: 0.2887, 27: 0.2887, 28: 0.2887}), SparseVector(6714, {11: 0.5, 19: 0.5, 29: 0.5, 30: 0.5}), SparseVector(6714, {11: 0.2236, 18: 0.2236, 27: 0.2236, 29: 0.2236, 31: 0.2236, 32: 0.2236, 33: 0.2236, 34: 0.2236, 35: 0.2236, 36: 0.2236, 37: 0.2236, 38: 0.2236, 39: 0.2236, 40: 0.2236, 41: 0.2236, 42: 0.2236, 43: 0.2236, 44: 0.2236, 45: 0.2236, 46: 0.2236})]

# %% [markdown]
# Compute mean for each feature

# %%
aa=data1.map(lambda x:(dict(zip(x.indices,x.values)))).map(lambda x: x.items()).reduce(lambda x,y:x+y)

# %%
task3=sc.parallelize(aa).reduceByKey(lambda x,y:float(x)+float(y)).map(lambda x: (x[0],float(x[1])/39774)).sortBy(lambda x:-x[1])
print task3.take(20)
# Out:
# [(11, 0.13827604360530327), (54, 0.060538666677720177), (35, 0.057411766119355105), (29, 0.05727859900184999), (3, 0.05349565793211743), (47, 0.052087442602091936), (105, 0.04564375839996118), (27, 0.038734039119421866), (115, 0.03598769191707431), (13, 0.03520318829860688), (4, 0.03327636774588432), (19, 0.03295939415838221), (15, 0.026707600112844603), (26, 0.02442899564591017), (79, 0.023409536831086035), (204, 0.023044180475298687), (228, 0.02257809505571638), (12, 0.022544486179313584), (312, 0.022261624518738813), (78, 0.021947441501501592)]

# %% [markdown]
# For each recipe subtract the mean value from each feature which is present

# %%
d = dict(task3.collect())
def subtract(x):
    s=[]
    for i,j in zip(x.values,[d[i] for i in x.indices]):
        s.append(i-j)
    return Vectors.sparse(6714,x.indices,s)
task4 = data1.map(subtract)

# %%
B=np.random.rand(6714,10)
out1=[]
for i in B:
    for j in i:
        out1.append(j)
print out1
# Out:
# [0.11925401815592107, 0.4876099972099164, 0.7440854228490864, 0.38673472602698544, 0.560299070774204, 0.2990239357096407, 0.8499440151253512, 0.5603766332201474, 0.8361786239097418, 0.14165437504671508, 0.7399082575731355, 0.4637817125151812, 0.503129637815031, 0.7452380180748706, 0.768341728113381, 0.8973117768914736, 0.3664078600200077, 0.9341939392372925, 0.3606620576160069, 0.40761642236499973, 0.5754732525970607, 0.7248392956228474, 0.22967397049987104, 0.22601574594136953, 0.44307496849724437, 0.6492775358676907, 0.8280893513091597, 0.5504006289125538, 0.9703026591965199, 0.4196039081747134, 0.5518598848243922, 0.6530597075784768, 0.67164952880616, 0.9940632298754611, 0.4018479942842712, 0.26905207197150594, 0.04050068521676253, 0.30676916595643977, 0.009623149363615524, 0.4438194502763022, 0.785474303115726, 0.5323552920220199, 0.6767886249047166, 0.9998620077184821, 0.30398323119337445, 0.48158038644088386, 0.7573275714566867, 0.11263616437128265, 0.5593525764681101, 0.07967928181040618, 0.831961896801425, 0.6257432245614122, 0.3933193309350387, 0.1028707199615092, 0.13507481352947182, 0.4758064932179069, 0.7042459589526049, 0.6284126542792673, 0.19184040416675008, 0.8571891709027308, 0.4148124771714282, 0.7944517385278493, 0.3700236478629183, 0.15430060835860826, 0.3224170371828081, 0.20496865966977074, 0.4823268199508123, 0.36461830209352886, 0.7243419599172454, 0.41687441785672785, 0.013856410970101374, 0.31126176504941205, 0.3657623404436898, 0.8121276113493983, 0.48271538226560884, 0.31034254450128373, 0.6497997403804723, 0.4375229089839864, 0.005229471155470122, 0.3243135634679203, 0.38537868391787244, 0.79586371673066, 0.34167658505111353, 0.6192494556628418, 0.24358874297639466, 0.6913384645017479, 0.9476963517696283, 0.4469930933823101, 0.9137985290625195, 0.4172714361597887, 0.23598101653882386, 0.02106319165316195, 0.38574291175309416, 0.9642340431290485, 0.3808024865529408, 0.46035676255583236, 0.9175357044248598, 0.662151533237678, 0.5351464696722896, 0.4864279520206507, 0.6065075179537054, 0.20910353951663174, 0.12881629444518505, 0.16843608353905226, 0.5328095200854511, 0.3052369994286763, 0.7674595261014309, 0.36558115705366756, 0.0641548296483303, 0.7862304520780594, 0.43600582936334065, 0.45478318798673456, 0.06506944727333319, 0.2709821545979034, 0.9157639405546338, 0.7796745763751045, 0.9544500444664867, 0.968615540527941, 0.981843163074117, 0.760611846762666, 0.002564017229824911, 0.3654384931163682, 0.6448226884187942, 0.7162024341118185, 0.954704617199169, 0.7477868172313497, 0.42145765406509916, 0.486116751406369, 0.910477351605495, 0.5430528660421977, 0.1211553146164861, 0.46853990541250523, 0.589702809295291, 0.6523636063071268, 0.13222999023228532, 0.1948193305256707, 0.36267691178304085, 0.019806061639254025, 0.23552998568506112, 0.022400737343945654, 0.025433123948467085, 0.994364179527381, 0.10607296224343377, 0.17633631201811795, 0.39147621557494994, 0.4437870846987446, 0.4834977522309952, 0.9462447333604317, 0.006947665553779014, 0.3924210196571689, 0.2565277116377829, 0.18315665611373821, 0.9854556908400994, 0.8781477279125158, 0.540172446455171, 0.7380859421312922, 0.7142397245444189, 0.6591043742051172, 0.75726707693743, 0.8970327155596324, 0.2312629385585261, 0.8484519290657372, 0.612884209847277, 0.7696372985456659, 0.10917095791434384, 0.26017455413806845, 0.28607573952588095, 0.13935362481023317, 0.6223554121549943, 0.34566569554352833, 0.2715329392673541, 0.818794910439923, 0.6163939080266577, 0.6906500889206658, 0.9548208994953764, 0.9450680674166704, 0.7550687865500457, 0.6745124217147624, 0.2186971508290807, 0.39633461960101535, 0.09862661643372184, 0.721813132767234, 0.5840401689655963, 0.5533619616298368, 0.08426127091288771, 0.5920105907611597, 0.9101499273979128, 0.020108187781871734, 0.5610825323771765, 0.5297100770937694, 0.6873517122399867, 0.30675930113130556, 0.5267289457666651, 0.07106081599581537, 0.4137226278635452, 0.4435578148298772, 0.8414713301239997, 0.7788566 ...

# %%
from pyspark.mllib.linalg import Matrix, Matrices
dm2 = Matrices.dense(6714, 10, out1)

# %%
mat = RowMatrix(task4)

# %%
new = mat.multiply(dm2)

# %%
pc = new.computePrincipalComponents(3)

# %%
new.multiply(pc).rows.collect()
# Out:
# [DenseVector([-4.5902, -0.3191, -0.3575]),
#  DenseVector([-4.5657, 0.4525, -0.2808]),
#  DenseVector([-5.3061, -0.4128, 0.2087]),
#  DenseVector([-2.6062, 0.0235, -0.0643]),
#  DenseVector([-6.4472, -0.7593, -0.0559]),
#  DenseVector([-4.6298, -0.3406, -0.314]),
#  DenseVector([-5.4621, 0.0032, -0.0802]),
#  DenseVector([-4.4898, 0.2227, -0.104]),
#  DenseVector([-5.3532, -0.0777, -0.2643]),
#  DenseVector([-4.0229, -0.5305, -0.6541]),
#  DenseVector([-5.3787, -0.0383, -0.4567]),
#  DenseVector([-5.7436, -0.6605, -0.2839]),
#  DenseVector([-4.7915, -0.5417, 0.0335]),
#  DenseVector([-5.7691, -0.3566, 0.4575]),
#  DenseVector([-5.3682, -0.056, 0.1883]),
#  DenseVector([-4.7469, -0.1354, -0.4472]),
#  DenseVector([-3.3211, -0.4751, -0.2602]),
#  DenseVector([-3.3888, -0.373, 0.5359]),
#  DenseVector([-3.0846, -0.4796, -0.0064]),
#  DenseVector([-4.9162, 0.0256, 0.2192]),
#  DenseVector([-5.1932, -0.2228, 0.3846]),
#  DenseVector([-3.8053, -0.0787, -0.666]),
#  DenseVector([-3.7818, -0.0604, 0.1547]),
#  DenseVector([-4.8182, -0.3374, -0.1032]),
#  DenseVector([-4.7694, -0.2251, -0.5567]),
#  DenseVector([-6.0039, -0.8408, -0.2345]),
#  DenseVector([-4.8617, 0.1416, 0.1034]),
#  DenseVector([-4.8662, -0.3313, 0.0809]),
#  DenseVector([-5.2688, 0.2077, -0.2517]),
#  DenseVector([-2.9887, -0.0651, -0.0214]),
#  DenseVector([-4.1999, -0.0411, 0.2297]),
#  DenseVector([-5.9982, -0.2317, 0.0045]),
#  DenseVector([-4.785, 0.3194, 0.8938]),
#  DenseVector([-6.3803, 0.0648, -0.3514]),
#  DenseVector([-4.3122, 0.2072, 0.2311]),
#  DenseVector([-4.8422, 0.1207, 0.009]),
#  DenseVector([-4.152, -0.2208, 0.232]),
#  DenseVector([-4.543, 0.1577, -0.2251]),
#  DenseVector([-4.1854, -0.3039, -0.2113]),
#  DenseVector([-5.4351, -0.5512, 0.3018]),
#  DenseVector([-4.3468, -0.5289, 0.223]),
#  DenseVector([-3.9736, -0.0937, -0.6694]),
#  DenseVector([-5.0979, -0.2438, -0.1825]),
#  DenseVector([-4.809, -0.3228, -0.2351]),
#  DenseVector([-4.8877, -0.7832, -0.4575]),
#  DenseVector([-3.8873, 0.1918, 0.0077]),
#  DenseVector([-3.64, -0.343, 0.6859]),
#  DenseVector([-4.301, -0.3117, 0.0483]),
#  DenseVector([-4.1846, -0.3246, -0.34]),
#  DenseVector([-3.7572, -0.2147, -0.0847]),
#  DenseVector([-5.3038, -0.175, 0.4461]),
#  DenseVector([-4.6745, -0.1049, 0.3086]),
#  DenseVector([-5.8879, -0.5902, -0.7242]),
#  DenseVector([-4.3066, -0.3679, -0.0043]),
#  DenseVector([-3.2372, -0.1323, -0.1111]),
#  DenseVector([-6.7643, -0.7803, 0.1056]),
#  DenseVector([-4.0671, -0.1492, -0.1475]),
#  DenseVector([-4.0219, -0.8284, 0.3897]),
#  DenseVector([-2.8572, 0.0936, 0.0229]),
#  DenseVector([-4.2044, 0.3381, 0.2768]),
#  DenseVector([-3.9742, -0.539, -0.3041]),
#  DenseVector([-5.6972, -0.5374, -0.3732]),
#  DenseVector([-5.3971, -0.152, -0.2285]),
#  DenseVector([-6.3347, 0.0136, -0.1303]),
#  DenseVector([-4.4145, 0.0109, 0.0466]),
#  DenseVector([-4.2966, -0.0583, 0.1037]),
#  DenseVector([-5.233, -0.382, -0.0174]),
#  DenseVector([-3.142, -0.715, -0.3721]),
#  DenseVector([-4.9629, -0.1538, -0.2421]),
#  DenseVector([-3.99, -0.431, -0.3154]),
#  DenseVector([-3.7722, -0.4884, 0.1258]),
#  DenseVector([-6.8069, -0.2868, 0.3521]),
#  DenseVector([-4.662, 0.0198, 0.3505]),
#  DenseVector([-4.0993, 0.0997, -0.2888]),
#  DenseVector([-5.066, -0.3552, -0.1503]),
#  DenseVector([-5.6794, -0.4821, -0.3314]),
#  DenseVector([-6.2627, 0.1927, 0.0333]),
#  DenseVector([-2.7395, -0.134, 0.2752]),
#  DenseVector([-3.4894, 0.5553, 0.1768]),
#  DenseVector([-3.9566, -0.3176, -0.0019]),
#  DenseVector([-5.9982, -0.2072, 0.0217]),
#  DenseVector([-4.2786, -0.9449, -0.1299]),
#  DenseVector([-5.7734, -0.2478, -0.2256]),
#  DenseVector([-5.9941, -0.2192, -0.5368]),
#  DenseVector([-3.3399, -0.6548, -0.4174]),
#  DenseVector([-4.5652, -0.1004, -0.2924]),
#  DenseVector([-4.7426, -0.0389, -0.3948]),
#  DenseVector([-4.0442, -0.4607, -0.4417]),
#  DenseVector([-2.2235, -0.1328, 0.4649]),
#  DenseVector([-4.3029, -0.0287, -0.3462]),
#  DenseVector([-3.1598, 0.0624, -0.1228]),
#  DenseVector([-4.6187, -0.4623, 0.242]),
#  DenseVector([-3.2794, -0.3032, 0.1944]),
#  DenseVector([-3.7136, -0.1588, 0.712]),
#  DenseVector([-3.7947, 0.387, -0.4205]),
#  DenseVector([-5.7288, 0.2443, -0.0573]),
#  DenseVector([-4.728, 0.3836, 0.3167]),
#  DenseVector([-5.931, -0.4693, 0.2024]),
#  DenseVector([-3.8956, 0.2247, 0.364]),
#  DenseVector([-3.8935, -0.3037, 0.3673]),
#  DenseVector([-4.076, -0.2404, 0.1863]),
#  DenseVector([-4.4098, -0.143, 0.4041]),
#  DenseVector([-4.3203, -0.1536, 0.1495]),
#  DenseVector([-3.5371, 0.412, -0.2504]),
#  DenseVector([-5.0271, -0.4805, 0.1563]),
#  DenseVector([-4.9668, 0.4427, 0.2259]),
#  DenseVector([-2.8646, 0.6023, -0.0992]),
#  DenseVector([-5.8507, -0.1469, 0.0972]),
#  DenseVector([-6.2774, 0.2177, 0.01]),
#  DenseVector([-4.8644, -0.6541, -0.1438]),
#  DenseVector([-5.5445, -0.0744, 0.0965]),
#  DenseVector([-4.7931, -0.4516, -0.1703]),
#  DenseVector([-3.9968, -0.4448, 0.1413]),
#  DenseVector([-5.0013, -0.2008, 0.1193]),
#  DenseVector([-5.7888, 0.0972, 0.1303]),
#  DenseVector([-4.257, -0.5542, 0.0815]),
#  DenseVector([-5.3989, -0.6421, -0.4532]),
#  DenseVector([-4.4682, 0.0879, 0.3702]),
#  DenseVector([-4.5069, -0.0789, -0.3143]),
#  DenseVector([-4.4052, -0.1224, -0.0139]),
#  DenseVector([-6.4235, -0.7766, 0.4933]),
#  DenseVector([-6.1339, -0.463, 0.147]),
#  DenseVector([-5.8027, 0.1024, 0.0966]),
#  DenseVector([-4.2373, -0.323, 0.1247]),
#  DenseVector([-3.778, -0.0763, -0.0313]),
#  DenseVector([-4.9662, 0.1509, -0.2136]),
#  DenseVector([-4.8098, -0.1244, 0.0613]),
#  DenseVector([-3.2911, 0.2016, -0.0393]),
#  DenseVector([-4.377, -0.3411, 0.2468]),
#  DenseVector([-5.0225, -0.0332, 0.3789]),
#  DenseVector([-5.3215, -0.4256, -0.0856]),
#  DenseVector([-5.2595, -0.2972, 0.0889]),
#  DenseVector([-3.0227, -0.2203, -0.0069]),
#  DenseVector([-3.5746, -0.4855, -0.1608]),
#  DenseVector([-3.888, 0.3359, 0.103]),
#  DenseVector([-5.2039, -0.3836, -0.2458]),
#  DenseVector([-4.9154, 0.1292, 0.2638]),
#  DenseVector([-2.8382, 0.1931, -0.303]),
#  DenseVector([-4.8074, 0.067, -0.3605]),
#  DenseVector([-5.0928, -0.1958, -0.3144]),
#  DenseVector([-3.3571, 0.0737, -0.027]),
#  DenseVector([-6.084, 0.0783, 0.0993]),
#  DenseVector([-6.1663, -0.0003, 0.079]),
#  DenseVector([-2.0736, -0.1654, 0.2869]),
#  DenseVector([-4.4545, -0.7524, -0.2745]),
#  DenseVector([-3.9647, -0.0733, 0.5659]),
#  DenseVector([-5.5444, -0.2085, 0.2813]),
#  DenseVector([-4.7953, -0.1065, 0.0985]),
#  DenseVector([-5.2076, -0.7746, 0.0631]),
#  DenseVector([-3.1142, -0.1262, -0.295]),
#  DenseVector([-5.6552, -0.988, 0.3637]),
#  DenseVector([-4.8626, -0.3156, 0.0866]),
#  DenseVector([-4.8681, -0.5466, 0.2796]),
#  DenseVector([-6.2217, -0.8098, -0.2023]),
#  DenseVector([-5.8719, 0.13, -0.2463]),
#  DenseVector([-4.2766, 0.1385, -0.0517]),
#  DenseVector([-4.2945, -0.0676, -0.0486]),
#  DenseVector([-5.2374, -0.491, -0.0392]),
#  DenseVector([-4.3491, 0.4587, -0.0369]),
#  DenseVector([-4.1798, 0.2474, -0.0665]),
#  DenseVector([-4.8849, -0.1349, -0.0327]),
#  DenseVector([-4.0372, 0.0688, 0.1173]),
#  DenseVector([-3.5441, 0.2136, 0.0157]),
#  DenseVector([-5.3523, -0.6694, -0.3819]),
#  DenseVector([-5.6253, -0.0531, -0.6142]),
#  DenseVector([-5.2367, -0.2291, -0.2101]),
#  DenseVector([-5.9113, -0.1371, -0.3008]),
#  DenseVector([-5.5109, 0.0401, -0.135]),
#  DenseVector([-5.0841, 0.0185, -0.3113]),
#  DenseVector([-5.2616, -0.2962, 0.0004]),
#  DenseVector([-4.7123, -0.3216, -0.2423]),
#  DenseVector([-3.5371, -0.5913, -0.159]),
#  DenseVector([-4.5791, -0.0342, -0.0655]),
#  DenseVector([-6.1179, -0.2925, 0.0201]),
#  DenseVector([-5.4565, -0.146, -0.0444]),
#  DenseVector([-4.2987, -0.2625, 0.0364]),
#  DenseVector([-4.3806, -0.5291, -0.1147]),
#  DenseVector([-5.0634, -0.3281, 0.1628]),
#  DenseVector([-5.6803, -0.6013, -0.7233]),
#  DenseVector([-5.7084, -0.3756, 0.043]),
#  DenseVector([-5.9191, -0.3671, -0.2907]),
#  DenseVector([-3.6882, -0.564, -0.2378]),
#  DenseVector([-4.8565, -0.2669, -0.5745]),
#  DenseVector([-5.89, 0.5414, -0.0441]),
#  DenseVector([-5.9724, -0.1628, -0.1604]),
#  DenseVector([-3.6693, -0.027, 0.1342]),
#  DenseVector([-4.9636, -0.0176, 0.0421]),
#  DenseVector([-4.9682, 0.3788, -0.8408]),
#  DenseVector([-3.4118, -0.1249, 0.352]),
#  DenseVector([-3.7828, 0.5267, -0.3646]),
#  DenseVector([-3.5094, -0.0909, 0.0243]),
#  DenseVector([-3.8991, -0.3052, -0.3368]),
#  DenseVector([-5.8789, -0.0581, -0.3056]),
#  DenseVector([-3.469, -0.3708, 0.2913]),
#  DenseVector([-4.3521, 0.1268, 0.2321]),
#  DenseVector([-4.7344, 0.4201, 0.2985]),
#  DenseVector([-3.2529, -0.2254, 0.4237]),
#  DenseVector([-4.6453, -0.3854, -0.185]),
#  DenseVector([-5.8205, 0.0989, -0.2379]),
#  DenseVector([-6.4263, 0.1886, 0.2414]),
#  DenseVector([-4.6665, -0.9081, -0.4618]),
#  DenseVector([-3.0524, -0.1332, 0.1648]),
#  DenseVector([-5.1466, -0.1228, -0.252]),
#  DenseVector([-5.3703, -0.072, -0.0499]),
#  DenseVector([-5.7538, -0.1745, -0.0571]),
#  DenseVector([-3.7203, -0.1551, 0.0461]),
#  DenseVector([-5.3091, -0.2144, 0.232]),
#  DenseVector([-4.0894, -0.4032, 0.3413]),
#  DenseVector([-4.2848, 0.3657, 0.3856]),
#  DenseVector([-4.6217, 0.1371, -0.0566]),
#  DenseVector([-5.902, -0.496, 0.4655]),
#  DenseVector([-6.3215, -0.3672, -0.1992]),
#  DenseVector([-5.1071, 0.0457, 0.5204]),
#  DenseVector([-3.6895, 0.0363, 0.1315]),
#  DenseVector([-5.5575, -0.0035, -0.4201]),
#  DenseVector([-2.7632, -0.0906, 0.2919]),
#  DenseVector([-5.6969, 0.4458, 0.1137]),
#  DenseVector([-5.7534, 0.1232, 0.2272]),
#  DenseVector([-4.8843, -0.4694, 0.2927]),
#  DenseVector([-4.0429, -0.5902, 0.1782]),
#  DenseVector([-4.5541, 0.1939, -0.1931]),
#  DenseVector([-3.0605, -0.3018, -0.0444]),
#  DenseVector([-4.2199, -0.2243, -0.3037]),
#  DenseVector([-3.7863, -0.3495, 0.0951]),
#  DenseVector([-4.5689, -0.6081, -0.4689]),
#  DenseVector([-4.8808, -0.1221, -0.0371]),
#  DenseVector([-4.9763, -0.5266, 0.5153]),
#  DenseVector([-4.2085, -0.2403, -0.8666]),
#  DenseVector([-4.876, -0.073, 0.5268]),
#  DenseVector([-5.5391, -0.259, 0.1217]),
#  DenseVector([-3.8346, -0.4939, 0.1481]),
#  DenseVector([-3.2784, 0.4679, 0.0001]),
#  DenseVector([-5.1007, 0.0611, 0.3353]),
#  DenseVector([-4.4363, 0.1435, -0.2038]),
#  DenseVector([-4.117, -0.1339, -0.3832]),
#  DenseVector([-4.7522, 0.0664, 0.3386]),
#  DenseVector([-4.5707, -0.8484, 0.5407]),
#  DenseVector([-6.1441, -0.4175, 0.2949]),
#  DenseVector([-3.2132, -0.3676, 0.0307]),
#  DenseVector([-5.8251, 0.2172, -0.1208]),
#  DenseVector([-3.8455, -0.4554, -0.1915]),
#  DenseVector([-5.3527, -0.4497, -0.3488]),
#  DenseVector([-5.4277, -0.4682, 0.32]),
#  DenseVector([-6.0879, -0.436, -0.3938]),
#  DenseVector([-5.577, -0.2568, 0.4171]),
#  DenseVector([-6.4957, -0.8547, 0.2689]),
#  DenseVector([-5.7923, -0.1809, 0.505]),
#  DenseVector([-3.9746, -0.6505, -0.0629]),
#  DenseVector([-3.3589, -0.7503, -0.1592]),
#  DenseVector([-5.8925, -0.185, 0.1478]),
#  DenseVector([-3.2048, -0.4046, -0.1186]),
#  DenseVector([-7.1386, -0.3296, -0.5948]),
#  DenseVector([-3.3611, -0.0401, 0.2692]),
#  DenseVector([-4.2481, -0.3569, 0.1903]),
#  DenseVector([-6.0993, 0.1355, 0.3974]),
#  DenseVector([-4.8854, 0.0438, -0.3133]),
#  DenseVector([-3.5417, -0.3916, -0.3215]),
#  DenseVector([-2.9157, 0.3632, 0.2419]),
#  DenseVector([-7.009, -0.3591, -0.2065]),
#  DenseVector([-4.4963, -0.5775, 0.2767]),
#  DenseVector([-5.5962, -0.0487, -0.1068]),
#  DenseVector([-3.677, 0.2498, -0.8067]),
#  DenseVector([-3.9949, 0.157, -0.4222]),
#  DenseVector([-5.4288, -0.5419, 0.0181]),
#  DenseVector([-3.7726, -0.3713, 0.6066]),
#  DenseVector([-4.7392, 0.03, 0.1516]),
#  DenseVector([-4.8381, -0.0765, -0.1333]),
#  DenseVector([-3.603, 0.2137, -0.6427]),
#  DenseVector([-3.1543, -0.1676, -0.1885]),
#  DenseVector([-4.6079, -0.2935, -0.0698]),
#  DenseVector([-6.3026, -0.3306, -0.3493]),
#  DenseVector([-3.2286, 0.6449, -0.1107]),
#  DenseVector([-5.3387, -0.0512, 0.2252]),
#  DenseVector([-3.8428, 0.1017, -0.0669]),
#  DenseVector([-5.0543, -0.0138, 0.2656]),
#  DenseVector([-5.0214, 0.115, 0.2496]),
#  DenseVector([-4.282, -0.2903, 0.0634]),
#  DenseVector([-3.083, 0.169, -0.2424]),
#  DenseVector([-4.4052, -0.0777, -0.0303]),
#  DenseVector([-4.8825, -0.004, -0.1581]),
#  DenseVector([-5.0044, -0.399, -0.2069]),
#  DenseVector([-5.1083, -0.3165, 0.019]),
#  DenseVector([-5.907, 0.2016, -0.4772]),
#  DenseVector([-4.5795, 0.0195, -0.4884]),
#  DenseVector([-3.4742, -0.1024, -0.2902]),
#  DenseVector([-5.5034, -0.1214, -0.3002]),
#  DenseVector([-5.0669, -0.5547, 0.058]),
#  DenseVector([-4.8694, -0.2942, 0.2524]),
#  DenseVector([-6.3705, -0.0663, -0.0152]),
#  DenseVector([-4.2354, -0.5436, 0.3349]),
#  DenseVector([-5.566, -0.4616, -0.1507]),
#  DenseVector([-5.0973, -0.3919, -0.4568]),
#  DenseVector([-4.1138, -0.3565, -0.3572]),
#  DenseVector([-5.9051, -0.0521, 0.0728]),
#  DenseVector([-9.0549, -1.1536, 0.1645]),
#  DenseVector([-6.2122, -0.4837, 0.1513]),
#  DenseVector([-4.6486, -0.1063, 0.1296]),
#  DenseVector([-5.171, -1.1533, -0.8196]),
#  DenseVector([-2.9322, -0.829, -0.223]),
#  DenseVector([-4.5139, -0.008, -0.3936]),
#  DenseVector([-5.1597, -0.327, -0.4167]),
#  DenseVector([-5.157, -0.0333, 0.0461]),
#  DenseVector([-4.6427, -0.1646, -0.3439]),
#  DenseVector([-5.3711, -0.4441, 0.2965]),
#  DenseVector([-5.5854, -0.1853, 0.5475]),
#  DenseVector([-3.9579, -1.0598, 0.2314]),
#  DenseVector([-4.9413, -0.5631, 0.0647]),
#  DenseVector([-5.8804, -0.2123, 0.0563]),
#  DenseVector([-2.8859, -0.0704, 0.4836]),
#  DenseVector([-3.8017, 0.3305, -0.0742]),
#  DenseVector([-5.3286, -0.2972, -0.1433]),
#  DenseVector([-5.9685, -0.5138, -0.4389]),
#  DenseVector([-5.755, -0.9806, 0.1119]),
#  DenseVector([-4.9332, -0.7007, 0.1761]),
#  DenseVector([-6.3161, 0.1923, -0.1331]),
#  DenseVector([-4.4256, -0.0655, 0.5887]),
#  DenseVector([-5.3314, 0.2884, -0.3399]),
#  DenseVector([-5.4607, -0.1979, -0.297]),
#  DenseVector([-4.2888, -0.2763, 0.3474]),
#  DenseVector([-5.3907, -0.3601, -0.1435]),
#  DenseVector([-5.9948, -0.9702, 0.4253]),
#  DenseVector([-6.0628, -0.3207, -0.3459]),
#  DenseVector([-5.2727, 0.0903, -0.4857]),
#  DenseVector([-4.8921, 0.0416, -0.1706]),
#  DenseVector([-4.4171, 0.0929, -0.108]),
#  DenseVector([-4.721, -0.252, 0.2479]),
#  DenseVector([-5.552, -0.104, 0.1386]),
#  DenseVector([-3.8835, 0.0548, 0.174]),
#  DenseVector([-4.0643, -0.3947, 0.1331]),
#  DenseVector([-3.9358, -0.0156, 0.1959]),
#  DenseVector([-4.8623, -0.517, 0.2111]),
#  DenseVector([-3.2451, 0.221, 0.2592]),
#  DenseVector([-5.2957, -0.554, -0.416]),
#  DenseVector([-6.0115, -0.3659, -0.4954]),
#  DenseVector([-4.0254, -0.4805, -0.0893]),
#  DenseVector([-5.0041, -0.2659, -0.1383]),
#  DenseVector([-2.9193, -0.0754, 0.1496]),
#  DenseVector([-3.9419, -0.4184, 0.0876]),
#  DenseVector([-6.0408, -0.6045, -0.3423]),
#  DenseVector([-4.1216, 0.0662, -0.4878]),
#  DenseVector([-6.2842, -0.5298, -0.075]),
#  DenseVector([-3.702, -0.7289, 0.2444]),
#  DenseVector([-6.6904, -0.1146, -0.3377]),
#  DenseVector([-5.9128, -0.334, 0.1012]),
#  DenseVector([-4.7113, -0.3093, -0.2068]),
#  DenseVector([-9.4155, -0.7797, 0.0787]),
#  DenseVector([-3.6394, -0.3903, -0.3391]),
#  DenseVector([-2.6633, -0.5061, 0.0043]),
#  DenseVector([-4.6219, -0.5936, 0.1349]),
#  DenseVector([-4.1763, -0.4159, -0.89]),
#  DenseVector([-3.3754, -0.2873, 0.4955]),
#  DenseVector([-4.6687, -0.5846, -0.1434]),
#  DenseVector([-3.2007, -0.1766, -0.2912]),
#  DenseVector([-3.9341, 0.0224, -0.2932]),
#  DenseVector([-5.8553, 0.2154, 0.1518]),
#  DenseVector([-2.9913, -0.3584, -0.3252]),
#  DenseVector([-5.6917, -0.5436, 0.4124]),
#  DenseVector([-5.5075, -0.0608, -0.0125]),
#  DenseVector([-5.0006, -0.0879, 0.9478]),
#  DenseVector([-5.8284, -0.3937, -0.4649]),
#  DenseVector([-4.1564, -0.4765, 0.1722]),
#  DenseVector([-5.6746, 0.0301, -0.1228]),
#  DenseVector([-5.4097, -0.1194, 0.0705]),
#  DenseVector([-5.2035, 0.3113, 0.208]),
#  DenseVector([-5.7333, -0.4595, -0.3504]),
#  DenseVector([-6.3548, 0.0461, -0.6605]),
#  DenseVector([-4.2831, -0.1371, 0.2163]),
#  DenseVector([-6.0369, 0.1287, -0.4297]),
#  DenseVector([-4.1702, -0.2182, -0.0469]),
#  DenseVector([-2.6569, -0.1704, 0.7648]),
#  DenseVector([-5.4767, -0.2291, -0.3841]),
#  DenseVector([-4.0104, -0.3045, -0.6367]),
#  DenseVector([-5.3486, -0.0585, 0.136]),
#  DenseVector([-4.8332, -0.4682, 0.101]),
#  DenseVector([-6.6579, 0.2964, 0.2335]),
#  DenseVector([-3.8263, -0.1829, -0.0031]),
#  DenseVector([-4.4278, 0.3116, -0.3148]),
#  DenseVector([-4.4357, -0.0348, 0.6138]),
#  DenseVector([-5.61, 0.1272, 0.2519]),
#  DenseVector([-3.8609, 0.1403, 0.4049]),
#  DenseVector([-6.4229, -0.2543, -0.0284]),
#  DenseVector([-5.5672, -0.1235, -0.1736]),
#  DenseVector([-5.0517, -0.4683, -0.2218]),
#  DenseVector([-5.7583, 0.1958, -0.0092]),
#  DenseVector([-4.7411, -0.369, -0.2682]),
#  DenseVector([-3.2289, 0.7109, -0.3653]),
#  DenseVector([-4.6943, 0.2071, 0.5682]),
#  DenseVector([-4.9221, -0.5801, 0.1953]),
#  DenseVector([-4.9038, -0.4543, -0.1384]),
#  DenseVector([-2.7778, -0.1007, 0.3385]),
#  DenseVector([-5.4407, -0.3661, -0.0552]),
#  DenseVector([-3.9012, -0.1176, 0.0835]),
#  DenseVector([-5.5318, 0.3702, 0.2865]),
#  DenseVector([-5.1741, -0.2773, 0.3527]),
#  DenseVector([-4.6082, -1.0575, -0.212]),
#  DenseVector([-5.163, -0.8028, 0.2071]),
#  DenseVector([-4.9069, -0.6564, -0.1561]),
#  DenseVector([-4.479, 0.2114, -0.0399]),
#  DenseVector([-5.228, 0.0496, 0.2643]),
#  DenseVector([-2.6285, -0.0532, 0.1909]),
#  DenseVector([-4.1182, 0.1094, 0.2121]),
#  DenseVector([-4.8042, -0.3314, -0.1253]),
#  DenseVector([-3.7125, 0.1212, -0.3319]),
#  DenseVector([-3.9465, -0.1057, 0.1212]),
#  DenseVector([-4.0481, -0.5277, 0.2372]),
#  DenseVector([-6.4094, -0.1659, 0.1725]),
#  DenseVector([-4.5106, 0.2976, -0.2865]),
#  DenseVector([-4.003, -0.5196, 0.0286]),
#  DenseVector([-6.9661, -0.3959, -0.2472]),
#  DenseVector([-3.8156, -0.2468, -0.1378]),
#  DenseVector([-5.1722, 0.0644, 0.0554]),
#  DenseVector([-6.5141, -0.3515, -0.0637]),
#  DenseVector([-4.2676, 0.0082, -0.1085]),
#  DenseVector([-5.402, -0.057, -0.1168]),
#  DenseVector([-5.6435, -0.233, 0.2021]),
#  DenseVector([-4.9036, -0.4663, 0.333]),
#  DenseVector([-6.4596, 0.1741, -0.3838]),
#  DenseVector([-5.5433, -0.3685, -0.0049]),
#  DenseVector([-5.2261, -0.3313, -0.1272]),
#  DenseVector([-5.5545, 0.2413, -0.1332]),
#  DenseVector([-3.6977, 0.0528, -0.3745]),
#  DenseVector([-4.8876, -0.3223, 0.2544]),
#  DenseVector([-4.49, -0.0607, -0.0259]),
#  DenseVector([-2.9405, -0.3609, 0.2104]),
#  DenseVector([-4.9204, -0.6547, 0.0229]),
#  DenseVector([-4.7433, 0.1844, -0.3206]),
#  DenseVector([-3.9161, -0.6403, -0.2986]),
#  DenseVector([-4.1714, 0.3293, -0.2202]),
#  DenseVector([-5.332, -0.5625, -0.3623]),
#  DenseVector([-5.5186, -0.1726, -0.253]),
#  DenseVector([-4.0712, -0.5747, 0.282]),
#  DenseVector([-4.0584, -0.3463, 0.0142]),
#  DenseVector([-3.0599, -0.4716, 0.2395]),
#  DenseVector([-6.1516, -0.1927, 0.2448]),
#  DenseVector([-4.5806, -0.0976, -0.2136]),
#  DenseVector([-6.249, 0.3023, -0.0603]),
#  DenseVector([-5.2072, -0.0036, 0.2298]),
#  DenseVector([-5.2889, -0.5921, -0.0104]),
#  DenseVector([-5.1662, -0.8301, -0.1129]),
#  DenseVector([-4.9036, 0.1026, -0.0279]),
#  DenseVector([-5.1524, -0.0498, 0.1937]),
#  DenseVector([-4.5083, 0.0924, 0.2333]),
#  DenseVector([-5.3513, -1.0809, 0.3299]),
#  DenseVector([-5.2321, 0.1, -0.1419]),
#  DenseVector([-6.223, -0.3552, 0.1496]),
#  DenseVector([-2.3966, -0.0701, -0.186]),
#  DenseVector([-6.1892, -0.1715, -0.3507]),
#  DenseVector([-4.674, -0.1746, 0.2186]),
#  DenseVector([-5.5659, 0.157, 0.2841]),
#  DenseVector([-6.083, 0.2186, 0.2508]),
#  DenseVector([-4.033, -0.3755, 0.0985]),
#  DenseVector([-5.1267, -0.4526, 0.0001]),
#  DenseVector([-5.3604, -0.5203, -0.5645]),
#  DenseVector([-3.5618, -0.7313, 0.2677]),
#  DenseVector([-5.6742, -0.1607, -0.0491]),
#  DenseVector([-3.0733, -0.1852, -0.0935]),
#  DenseVector([-3.8028, 0.049, -0.0279]),
#  DenseVector([-4.6368, -0.2176, 0.0895]),
#  DenseVector([-4.7792, -0.0287, 0.3666]),
#  DenseVector([-5.3639, -0.4759, 0.1087]),
#  DenseVector([-4.8104, 0.4597, -0.0205]),
#  DenseVector([-4.4958, -0.2337, -0.2912]),
#  DenseVector([-5.0179, -0.6181, -0.1613]),
#  DenseVector([-4.8211, 0.1285, 0.111]),
#  DenseVector([-4.3911, 0.0831, 0.0328]),
#  DenseVector([-3.8939, -0.0269, 0.3647]),
#  DenseVector([-4.8409, -0.517, 0.3021]),
#  DenseVector([-5.2289, -0.3587, -0.4852]),
#  DenseVector([-6.6074, -0.602, -0.118]),
#  DenseVector([-4.3262, -0.0122, 0.0518]),
#  DenseVector([-4.8327, -0.0749, -0.4696]),
#  DenseVector([-4.4039, 0.0899, -0.1931]),
#  DenseVector([-6.7593, -0.3327, 0.1414]),
#  DenseVector([-3.5856, -0.3938, -0.4043]),
#  DenseVector([-4.4599, -0.6563, 0.6423]),
#  DenseVector([-4.4751, 0.0668, 0.2062]),
#  DenseVector([-4.98, 0.0277, 0.3343]),
#  DenseVector([-5.9686, 0.3578, -0.3055]),
#  DenseVector([-4.3673, -0.3251, -0.1438]),
#  DenseVector([-4.3335, -0.2454, -0.1528]),
#  DenseVector([-4.2393, -0.1616, 0.565]),
#  DenseVector([-5.1382, 0.1847, -0.2886]),
#  DenseVector([-3.9627, -0.0128, 0.016]),
#  DenseVector([-4.3154, -0.0477, -0.144]),
#  DenseVector([-6.6708, -0.3391, 0.2352]),
#  DenseVector([-4.314, -0.1586, -0.2645]),
#  DenseVector([-4.4431, -0.7701, 0.75]),
#  DenseVector([-5.2526, -0.2678, -0.3864]),
#  DenseVector([-7.5696, -0.0476, 0.3344]),
#  DenseVector([-5.7097, -0.3464, 0.3856]),
#  DenseVector([-6.0229, -0.1988, -0.2612]),
#  DenseVector([-3.75, -0.8129, 0.0928]),
#  DenseVector([-4.9778, 0.1339, -0.0029]),
#  DenseVector([-5.1997, -0.0108, -0.4766]),
#  DenseVector([-4.8211, -0.3347, 0.2871]),
#  DenseVector([-4.6568, 0.0441, -0.1087]),
#  DenseVector([-3.9879, 0.3076, -0.2011]),
#  DenseVector([-4.4838, -0.1743, -0.2682]),
#  DenseVector([-6.2567, -0.2216, -0.3032]),
#  DenseVector([-6.1723, -0.2683, 0.3044]),
#  DenseVector([-5.651, -0.4298, -0.2872]),
#  DenseVector([-4.3692, 0.0882, -0.1245]),
#  DenseVector([-3.4147, -0.0249, -0.0514]),
#  DenseVector([-4.4304, -0.2247, -0.4633]),
#  DenseVector([-3.8145, -0.2073, 0.0674]),
#  DenseVector([-4.4105, -0.1034, 0.1069]),
#  DenseVector([-4.0732, 0.0675, 0.5878]),
#  DenseVector([-5.7337, -0.6009, -0.1275]),
#  DenseVector([-4.9191, 0.195, 0.442]),
#  DenseVector([-2.8502, -0.4337, -0.0952]),
#  DenseVector([-3.7799, -0.2356, 0.499]),
#  DenseVector([-4.6728, -0.7331, 0.2615]),
#  DenseVector([-5.4937, -0.2324, 0.03]),
#  DenseVector([-4.2261, 0.0692, -0.0077]),
#  DenseVector([-5.889, -0.0268, -0.0731]),
#  DenseVector([-4.8132, 0.1685, -0.0604]),
#  DenseVector([-3.814, 0.1464, 0.6678]),
#  DenseVector([-4.624, 0.5723, 0.2122]),
#  DenseVector([-3.814, -0.2821, -0.521]),
#  DenseVector([-4.996, -0.1822, -0.44]),
#  DenseVector([-3.9425, -0.1646, -0.423]),
#  DenseVector([-4.5103, -0.0774, 0.0207]),
#  DenseVector([-5.5068, -0.2718, 0.471]),
#  DenseVector([-5.0066, 0.2507, -0.3773]),
#  DenseVector([-5.4346, 0.4138, 0.0989]),
#  DenseVector([-5.2999, 0.0321, -0.1012]),
#  DenseVector([-4.8379, 0.1994, 0.003]),
#  DenseVector([-6.1159, 0.1438, -0.1229]),
#  DenseVector([-5.0627, -0.4147, 0.2317]),
#  DenseVector([-4.9982, -0.3446, -0.2676]),
#  DenseVector([-4.7095, 0.0599, -0.1599]),
#  DenseVector([-5.3755, 0.0341, -0.3238]),
#  DenseVector([-4.2329, -0.4816, -0.2633]),
#  DenseVector([-4.9351, -0.431, -0.1547]),
#  DenseVector([-4.7976, -1.2814, -0.2467]),
#  DenseVector([-3.411, 0.3418, 0.0318]),
#  DenseVector([-5.2599, 0.2306, -0.144]),
#  DenseVector([-4.9667, -0.2904, 0.3025]),
#  DenseVector([-6.3458, -0.0266, -0.1513]),
#  DenseVector([-4.1353, -0.0906, -0.6694]),
#  DenseVector([-3.9951, -0.1089, -0.6897]),
#  DenseVector([-5.0903, -0.106, 0.0999]),
#  DenseVector([-3.9053, 0.3634, -0.1268]),
#  DenseVector([-4.4619, -0.1189, 0.1677]),
#  DenseVector([-3.3751, -0.29, 0.0718]),
#  DenseVector([-5.3126, -0.5077, 0.1683]),
#  DenseVector([-4.6106, 0.0792, -0.4589]),
#  DenseVector([-4.1975, -0.0177, -0.1171]),
#  DenseVector([-5.9654, 0.162, -0.0799]),
#  DenseVector([-6.7333, -0.0646, 0.2117]),
#  DenseVector([-5.0463, -0.2847, 0.5009]),
#  DenseVector([-6.0657, -0.5581, 0.1523]),
#  DenseVector([-4.1852, -0.3491, -0.1478]),
#  DenseVector([-4.8526, -0.3441, -0.0686]),
#  DenseVector([-3.6843, -0.7908, -0.4759]),
#  DenseVector([-5.4918, -0.2505, 0.1638]),
#  DenseVector([-4.0939, -0.6748, -0.3692]),
#  DenseVector([-6.2327, -0.0715, 0.3216]),
#  DenseVector([-3.8494, 0.0303, 0.165]),
#  DenseVector([-4.403, 0.2967, -0.2422]),
#  DenseVector([-4.8253, 0.0791, 0.1183]),
#  DenseVector([-3.0684, -0.2386, -0.1353]),
#  DenseVector([-5.6209, -0.7323, -0.1815]),
#  DenseVector([-5.1096, -0.0199, -0.0034]),
#  DenseVector([-4.4059, -0.1427, 0.0264]),
#  DenseVector([-2.9891, -0.4089, -0.255]),
#  DenseVector([-2.2991, -0.1153, -0.2579]),
#  DenseVector([-4.4096, 0.1427, -0.4178]),
#  DenseVector([-2.824, -0.8843, -0.5578]),
#  DenseVector([-4.5413, -0.19, 0.0805]),
#  DenseVector([-3.3545, -0.4215, 0.0616]),
#  DenseVector([-4.0891, -0.2928, -0.2341]),
#  DenseVector([-3.5978, -0.6033, 0.0119]),
#  DenseVector([-4.0723, -0.2973, 0.079]),
#  DenseVector([-5.1658, -0.4039, 0.0641]),
#  DenseVector([-4.1841, -0.1007, -0.1089]),
#  DenseVector([-6.545, -0.8375, 0.1225]),
#  DenseVector([-6.2413, 0.0654, -0.5649]),
#  DenseVector([-6.7677, -0.1934, -0.0644]),
#  DenseVector([-7.1785, 0.1346, -0.469]),
#  DenseVector([-4.4999, 0.1156, -0.6949]),
#  DenseVector([-3.5196, -0.846, -0.143]),
#  DenseVector([-4.6295, -0.3002, -0.5367]),
#  DenseVector([-5.3451, -0.3154, 0.1326]),
#  DenseVector([-4.6182, 0.15, -0.0272]),
#  DenseVector([-6.0439, -0.2961, -0.0386]),
#  DenseVector([-4.2375, -0.6951, -0.5989]),
#  DenseVector([-3.0043, -0.4852, -0.6695]),
#  DenseVector([-3.7144, -0.4611, -0.066]),
#  DenseVector([-5.4229, 0.2414, -0.384]),
#  DenseVector([-4.097, -0.0216, 0.295]),
#  DenseVector([-5.556, -0.5946, -0.3122]),
#  DenseVector([-5.3414, 0.2213, -0.0943]),
#  DenseVector([-2.9972, -0.1319, 0.091]),
#  DenseVector([-4.0177, -0.1416, -0.1304]),
#  DenseVector([-4.8048, 0.0613, -0.2991]),
#  DenseVector([-4.817, 0.1423, -0.1824]),
#  DenseVector([-4.8436, 0.0032, -0.3829]),
#  DenseVector([-4.8032, -0.5327, -0.2106]),
#  DenseVector([-6.362, -0.2943, 0.1271]),
#  DenseVector([-4.8212, -0.7387, -0.3843]),
#  DenseVector([-3.7456, -0.2874, -0.0618]),
#  DenseVector([-3.6264, -0.1397, 0.0895]),
#  DenseVector([-4.8612, -0.2434, 0.481]),
#  DenseVector([-5.1166, -0.4038, -0.0389]),
#  DenseVector([-5.0491, -0.5265, 0.4247]),
#  DenseVector([-5.5304, 0.3417, -0.2278]),
#  DenseVector([-4.3607, -0.4807, -0.1746]),
#  DenseVector([-4.8903, 0.0489, 0.1116]),
#  DenseVector([-5.4152, -0.195, 0.7938]),
#  DenseVector([-5.4204, 0.1905, -0.2496]),
#  DenseVector([-4.0411, 0.0055, -0.3173]),
#  DenseVector([-4.2766, 0.0471, 0.4035]),
#  DenseVector([-4.1337, 0.1679, -0.1554]),
#  DenseVector([-3.457, -0.4971, 0.092]),
#  DenseVector([-3.9798, 0.1488, -0.1064]),
#  DenseVector([-6.2651, -0.6919, 0.2322]),
#  DenseVector([-4.3633, -0.4016, -0.1443]),
#  DenseVector([-4.8864, -0.2198, -0.2173]),
#  DenseVector([-5.9487, 0.029, 0.0677]),
#  DenseVector([-4.834, -0.6679, -0.0815]),
#  DenseVector([-4.6269, -0.1438, -0.2368]),
#  DenseVector([-6.1029, -0.2827, -0.1206]),
#  DenseVector([-4.135, 0.437, 0.0535]),
#  DenseVector([-3.9574, -0.7812, -0.5812]),
#  DenseVector([-4.3774, -0.1655, -0.2411]),
#  DenseVector([-4.121, -0.2213, 0.3641]),
#  DenseVector([-5.3406, -0.5665, -0.237]),
#  DenseVector([-5.5165, -0.1408, -0.1555]),
#  DenseVector([-4.9478, -0.3036, -0.2013]),
#  DenseVector([-4.9259, 0.053, 0.1447]),
#  DenseVector([-2.8342, -0.142, 0.1232]),
#  DenseVector([-4.5671, -0.213, 0.2381]),
#  DenseVector([-4.318, -0.5639, 0.174]),
#  DenseVector([-4.7737, -0.1168, -0.0895]),
#  DenseVector([-4.1701, 0.3582, 0.1506]),
#  DenseVector([-4.5778, -0.4332, 0.4018]),
#  DenseVector([-5.3538, -0.2318, -0.0998]),
#  DenseVector([-4.9948, 0.4904, -0.6029]),
#  DenseVector([-5.6581, -0.3456, -0.1115]),
#  DenseVector([-4.3772, 0.3582, -0.5962]),
#  DenseVector([-5.2153, 0.1514, -0.0611]),
#  DenseVector([-4.1712, -0.3751, 0.1033]),
#  DenseVector([-3.4469, -0.2964, -0.3273]),
#  DenseVector([-3.6712, 0.0983, 0.3198]),
#  DenseVector([-5.262, -0.3188, -0.186]),
#  DenseVector([-3.6335, 0.2772, 0.3583]),
#  DenseVector([-5.2282, 0.331, 0.0082]),
#  DenseVector([-5.6042, -0.5251, 0.5993]),
#  DenseVector([-5.3954, 0.378, 0.0485]),
#  DenseVector([-4.1879, 0.0055, -0.1124]),
#  DenseVector([-5.6039, 0.3507, -0.1153]),
#  DenseVector([-4.9151, -0.4711, -0.4382]),
#  DenseVector([-5.502, -0.4495, -0.6563]),
#  DenseVector([-3.4481, -0.786, -0.2319]),
#  DenseVector([-4.7312, -0.5196, -0.4158]),
#  DenseVector([-3.3383, -0.0679, 0.2567]),
#  DenseVector([-5.6818, 0.3399, -0.2898]),
#  DenseVector([-5.7632, -0.2918, 0.4123]),
#  DenseVector([-6.8241, -0.4316, 0.1119]),
#  DenseVector([-2.7719, -0.4841, 0.0563]),
#  DenseVector([-6.301, -0.6659, 0.0257]),
#  DenseVector([-4.3414, -0.153, -0.0121]),
#  DenseVector([-4.5621, -0.1081, 0.5339]),
#  DenseVector([-6.0614, -0.0467, 0.2945]),
#  DenseVector([-5.8813, -0.2005, -0.1047]),
#  DenseVector([-3.5746, -0.4824, -0.2065]),
#  DenseVector([-5.5862, -0.1126, 0.1935]),
#  DenseVector([-2.5716, -0.6923, 0.1371]),
#  DenseVector([-5.0805, -0.5201, -0.3556]),
#  DenseVector([-3.9509, 0.2193, -0.2677]),
#  DenseVector([-4.3673, 0.0126, -0.25]),
#  DenseVector([-5.2063, 0.138, -0.3502]),
#  DenseVector([-4.4767, 0.2093, -0.1571]),
#  DenseVector([-7.3372, 0.2199, -0.5589]),
#  DenseVector([-5.4042, -0.6939, -0.0435]),
#  DenseVector([-5.9719, 0.2841, 0.0289]),
#  DenseVector([-5.8706, 0.2024, -0.1972]),
#  DenseVector([-3.1981, 0.1035, 0.2144]),
#  DenseVector([-5.6685, -0.2567, -0.3539]),
#  DenseVector([-4.9521, -0.0312, -0.1618]),
#  DenseVector([-4.3754, 0.0619, 0.0393]),
#  DenseVector([-4.1438, -0.3503, 0.2407]),
#  DenseVector([-7.1072, 0.2395, -0.0526]),
#  DenseVector([-4.4565, 0.0775, -0.2454]),
#  DenseVector([-4.5435, -0.0698, -0.1052]),
#  DenseVector([-4.9275, -0.2951, -0.337]),
#  DenseVector([-4.0313, 0.3095, -0.1601]),
#  DenseVector([-6.4046, -0.2884, 0.139]),
#  DenseVector([-5.388, 0.1421, -0.0361]),
#  DenseVector([-6.3206, 0.2735, 0.8074]),
#  DenseVector([-7.1943, -0.1467, -0.3315]),
#  DenseVector([-6.8155, -0.1827, -0.3598]),
#  DenseVector([-5.1226, 0.1913, 0.6619]),
#  DenseVector([-4.3814, -0.2318, -0.2247]),
#  DenseVector([-5.7141, -0.4562, 0.714]),
#  DenseVector([-3.1637, -0.1856, -0.5837]),
#  DenseVector([-4.4599, 0.1776, -0.006]),
#  DenseVector([-6.5863, -0.1301, 0.1024]),
#  DenseVector([-6.493, -0.3576, 0.4171]),
#  DenseVector([-5.6521, -0.0975, 0.1265]),
#  DenseVector([-3.9787, -0.449, 0.0572]),
#  DenseVector([-4.7758, -0.5126, 0.2802]),
#  DenseVector([-5.1939, -0.6204, 0.0364]),
#  DenseVector([-3.2459, -0.2851, 0.1565]),
#  DenseVector([-5.3171, -0.0942, -0.008]),
#  DenseVector([-2.9535, -0.3397, -0.2929]),
#  DenseVector([-5.8763, -0.7012, 0.1432]),
#  DenseVector([-4.7891, -0.6105, -0.008]),
#  DenseVector([-4.6576, -0.1256, -0.4045]),
#  DenseVector([-5.659, 0.2445, 0.0233]),
#  DenseVector([-4.6098, -0.0565, -0.0701]),
#  DenseVector([-4.8968, -0.2229, -0.2587]),
#  DenseVector([-5.0153, -0.2223, -0.1927]),
#  DenseVector([-5.7194, -0.6178, -0.0463]),
#  DenseVector([-3.7979, -0.493, 0.2849]),
#  DenseVector([-5.0383, 0.1797, 0.003]),
#  DenseVector([-6.0463, -0.2115, 0.2258]),
#  DenseVector([-3.7545, -0.2981, 0.1097]),
#  DenseVector([-5.8683, -0.0824, -0.0359]),
#  DenseVector([-4.7941, -0.482, -0.012]),
#  DenseVector([-5.0077, -0.3983, -0.2715]),
#  DenseVector([-4.8156, -0.037, 0.304]),
#  DenseVector([-5.3641, 0.2782, -0.3726]),
#  DenseVector([-5.0376, -0.4514, 0.1903]),
#  DenseVector([-6.5826, -0.6144, 0.0562]),
#  DenseVector([-4.2638, 0.2357, 0.0446]),
#  DenseVector([-3.5756, 0.2669, -0.4141]),
#  DenseVector([-4.0569, -0.0695, 0.2592]),
#  DenseVector([-5.4303, 0.2746, -0.3333]),
#  DenseVector([-3.7739, -0.307, -0.2743]),
#  DenseVector([-5.4083, -0.1776, 0.4291]),
#  DenseVector([-4.9612, -0.0283, -0.1473]),
#  DenseVector([-6.7922, 0.2181, 0.3512]),
#  DenseVector([-4.8255, -0.7047, -0.0409]),
#  DenseVector([-4.6806, -0.2718, 0.1597]),
#  DenseVector([-4.4502, -0.4044, -0.354]),
#  DenseVector([-3.139, -0.2961, -0.4056]),
#  DenseVector([-5.579, -0.4643, -0.0127]),
#  DenseVector([-4.2896, 0.193, 0.1662]),
#  DenseVector([-5.0107, -0.3785, -0.0963]),
#  DenseVector([-3.943, -0.0551, 0.2024]),
#  DenseVector([-5.3006, -0.1689, 0.3569]),
#  DenseVector([-5.0432, -0.7979, -0.1409]),
#  DenseVector([-5.9694, -0.1219, -0.1248]),
#  DenseVector([-5.864, 0.0062, 0.0059]),
#  DenseVector([-5.7187, -0.1005, -0.1054]),
#  DenseVector([-4.1552, -0.3212, -0.3113]),
#  DenseVector([-4.2705, -0.5951, -0.4761]),
#  DenseVector([-4.2207, 0.4973, -0.0327]),
#  DenseVector([-5.1501, 0.0196, 0.0129]),
#  DenseVector([-3.7504, -0.0591, -0.5585]),
#  DenseVector([-5.1596, 0.2582, -0.3997]),
#  DenseVector([-5.0961, -0.0212, 0.4798]),
#  DenseVector([-5.7917, -0.0739, 0.1597]),
#  DenseVector([-5.4707, -0.1791, 0.0406]),
#  DenseVector([-5.6772, -0.7318, 0.7668]),
#  DenseVector([-5.016, -0.5075, -0.0657]),
#  DenseVector([-4.6555, 0.1567, 0.4119]),
#  DenseVector([-2.6396, -0.2267, -0.0663]),
#  DenseVector([-4.7867, -0.207, -0.2782]),
#  DenseVector([-6.1589, 0.0389, 0.2649]),
#  DenseVector([-5.584, 0.4522, -0.2381]),
#  DenseVector([-4.0143, -0.1012, -0.1517]),
#  DenseVector([-3.9553, -0.9451, -0.3333]),
#  DenseVector([-5.3684, -0.2448, 0.1986]),
#  DenseVector([-4.4431, 0.6765, -0.3254]),
#  DenseVector([-4.9116, -0.3325, -0.6043]),
#  DenseVector([-5.5257, -0.1943, 0.0188]),
#  DenseVector([-5.9976, -0.0953, 0.1728]),
#  DenseVector([-6.1295, -0.098, -0.3326]),
#  DenseVector([-3.3586, -0.0137, 0.3718]),
#  DenseVector([-5.387, -0.6967, 0.0078]),
#  DenseVector([-4.8428, -0.1968, 0.0046]),
#  DenseVector([-3.9656, -0.2918, -0.185]),
#  DenseVector([-5.3191, 0.0121, -0.1339]),
#  DenseVector([-3.3957, 0.1843, -0.0033]),
#  DenseVector([-4.6838, -0.2732, -0.0026]),
#  DenseVector([-3.584, -0.2026, -0.09]),
#  DenseVector([-3.7185, -0.28, -0.2854]),
#  DenseVector([-3.6144, 0.0698, 0.6052]),
#  DenseVector([-7.1918, -0.0606, 0.2818]),
#  DenseVector([-2.5255, -0.4446, -0.36]),
#  DenseVector([-7.5283, -0.0735, -0.1355]),
#  DenseVector([-4.5924, 0.0119, 0.2453]),
#  DenseVector([-4.6366, -0.1498, 0.4271]),
#  DenseVector([-4.7699, -0.6359, -0.1086]),
#  DenseVector([-4.9612, -0.0864, 0.2424]),
#  DenseVector([-4.9258, -0.5867, -0.0656]),
#  DenseVector([-5.3423, -0.4099, -0.0788]),
#  DenseVector([-3.9366, -0.7434, -0.3388]),
#  DenseVector([-3.2718, -0.2862, -0.0732]),
#  DenseVector([-3.9795, -0.2362, -0.08]),
#  DenseVector([-5.9397, -0.0001, 0.0688]),
#  DenseVector([-5.7061, -0.05, 0.0357]),
#  DenseVector([-7.6741, -0.2103, 0.2183]),
#  DenseVector([-4.5054, -0.4735, 0.0257]),
#  DenseVector([-5.813, -0.2775, -0.1106]),
#  DenseVector([-4.1979, -0.7405, -0.5072]),
#  DenseVector([-5.636, -0.0204, -0.0456]),
#  DenseVector([-3.5954, -0.6122, -0.0479]),
#  DenseVector([-3.1176, -0.3691, 0.1594]),
#  DenseVector([-5.1356, 0.0043, -0.0407]),
#  DenseVector([-2.9153, -0.3849, 0.3714]),
#  DenseVector([-3.9189, -0.0748, -0.4027]),
#  DenseVector([-4.6124, 0.2975, -0.1377]),
#  DenseVector([-4.9642, -0.7213, 0.2668]),
#  DenseVector([-5.388, -0.3947, -0.3219]),
#  DenseVector([-5.4925, -0.0903, 0.1126]),
#  DenseVector([-4.8329, -0.2619, 0.1887]),
#  DenseVector([-4.5688, -0.1733, 0.1372]),
#  DenseVector([-4.7176, -0.1947, -0.0814]),
#  DenseVector([-4.6077, -0.1991, 0.264]),
#  DenseVector([-5.2969, 0.0087, 0.2659]),
#  DenseVector([-4.4408, 0.1188, -0.3616]),
#  DenseVector([-4.4438, 0.084, 0.1948]),
#  DenseVector([-6.4414, 0.117, 0.1867]),
#  DenseVector([-5.5023, -0.64, 0.2222]),
#  DenseVector([-4.8107, 0.0554, 0.3903]),
#  DenseVector([-5.0614, -0.0323, 0.1623]),
#  DenseVector([-3.4745, -0.4979, -0.4784]),
#  DenseVector([-3.6627, -0.3881, -0.0886]),
#  DenseVector([-5.345, -0.3011, -0.3533]),
#  DenseVector([-5.6051, -0.2259, 0.5423]),
#  DenseVector([-4.6601, 0.0364, 0.3703]),
#  DenseVector([-3.1862, 0.3012, -0.02]),
#  DenseVector([-5.7703, -0.0573, -0.4466]),
#  DenseVector([-4.483, 0.1102, 0.4331]),
#  DenseVector([-2.6629, 0.5101, 0.3783]),
#  DenseVector([-5.427, -0.0517, -0.0354]),
#  DenseVector([-4.5503, -0.6934, -0.1165]),
#  DenseVector([-5.6873, 0.2615, 0.2446]),
#  DenseVector([-4.6556, 0.2365, 0.2426]),
#  DenseVector([-5.4918, -0.3264, -0.2773]),
#  DenseVector([-5.7042, -0.1163, 0.121]),
#  DenseVector([-4.7106, -0.6053, 0.4864]),
#  DenseVector([-4.2479, -0.0963, 0.1476]),
#  DenseVector([-4.2365, -0.0846, -0.0522]),
#  DenseVector([-5.0359, -0.6756, 0.3815]),
#  DenseVector([-5.5947, -0.5286, -0.5347]),
#  DenseVector([-5.2526, -0.0884, 0.164]),
#  DenseVector([-3.1738, 0.0671, -0.0485]),
#  DenseVector([-3.2028, 0.4699, -0.2057]),
#  DenseVector([-4.9651, -0.1792, -0.1285]),
#  DenseVector([-5.5672, -0.2683, -0.2268]),
#  DenseVector([-5.2994, -0.2978, 0.4664]),
#  DenseVector([-4.2602, -0.5911, 0.1875]),
#  DenseVector([-3.7827, -0.2691, 0.319]),
#  DenseVector([-5.5254, 0.1795, 0.0571]),
#  DenseVector([-4.5736, -0.141, 0.0937]),
#  DenseVector([-5.4389, 0.016, 0.2069]),
#  DenseVector([-2.9203, 0.4807, 0.2637]),
#  DenseVector([-3.1459, -0.2355, -0.0034]),
#  DenseVector([-6.864, -0.3208, -0.0709]),
#  DenseVector([-5.1749, -0.852, -0.1639]),
#  DenseVector([-5.1685, -0.4192, 0.0931]),
#  DenseVector([-5.6758, -0.1249, -0.1021]),
#  DenseVector([-5.8683, 0.0392, -0.1471]),
#  DenseVector([-3.3806, -0.0893, -0.402]),
#  DenseVector([-5.0849, -0.1522, -0.159]),
#  DenseVector([-4.1727, 0.0946, 0.0059]),
#  DenseVector([-3.2452, -0.3922, 0.6369]),
#  DenseVector([-4.5224, 0.2933, -0.4206]),
#  DenseVector([-6.1495, -0.5282, -0.1782]),
#  DenseVector([-3.9541, -0.0894, -0.5137]),
#  DenseVector([-3.3793, 0.0089, -0.2972]),
#  DenseVector([-4.7345, -0.0265, 0.2775]),
#  DenseVector([-7.6064, -0.2688, 0.0143]),
#  DenseVector([-4.2677, 0.3131, -0.0153]),
#  DenseVector([-4.1598, -0.6957, -0.4604]),
#  DenseVector([-3.4018, -0.3894, -0.0177]),
#  DenseVector([-6.8232, 0.0183, -0.3474]),
#  DenseVector([-3.077, 0.0769, -0.2553]),
#  DenseVector([-6.3765, -0.5542, -0.7987]),
#  DenseVector([-4.0051, -0.0675, 0.0097]),
#  DenseVector([-3.0071, -0.1218, 0.4435]),
#  DenseVector([-3.9904, 0.0402, -0.1855]),
#  DenseVector([-4.031, 0.3845, 0.0514]),
#  DenseVector([-6.5772, -0.026, -0.2117]),
#  DenseVector([-3.6359, -0.1291, 0.4856]),
#  DenseVector([-4.1802, -0.2315, -0.0707]),
#  DenseVector([-2.8424, 0.2634, 0.2944]),
#  DenseVector([-3.7918, -0.4134, -0.967]),
#  DenseVector([-4.5009, -0.2318, -0.0447]),
#  DenseVector([-6.16, -0.1698, 0.1156]),
#  DenseVector([-6.71, -0.1234, 0.1908]),
#  DenseVector([-5.9037, -0.5404, -0.1585]),
#  DenseVector([-5.854, -0.2069, 0.1813]),
#  DenseVector([-6.2903, -0.1491, -0.0774]),
#  DenseVector([-5.1025, -0.1781, 0.0304]),
#  DenseVector([-3.3894, 0.0667, 0.1087]),
#  DenseVector([-5.0098, -0.1155, -0.0995]),
#  DenseVector([-3.0732, -0.4295, 0.2058]),
#  DenseVector([-4.8917, 0.0742, 0.2131]),
#  DenseVector([-5.5616, 0.3626, 0.108]),
#  DenseVector([-6.4606, -0.7187, 0.2573]),
#  DenseVector([-2.9475, -0.0777, 0.1532]),
#  DenseVector([-4.8177, -0.2207, 0.2044]),
#  DenseVector([-4.3572, 0.3307, -0.261]),
#  DenseVector([-4.2063, -0.1705, 0.2888]),
#  DenseVector([-4.8845, -0.7073, -0.22]),
#  DenseVector([-4.3861, -0.3535, -0.2168]),
#  DenseVector([-6.0076, -0.6118, -0.3195]),
#  DenseVector([-2.7476, -0.4797, -0.0815]),
#  DenseVector([-3.6983, 0.0378, 0.0973]),
#  DenseVector([-2.8367, -0.3924, 0.2874]),
#  DenseVector([-5.7116, -0.0536, 0.4614]),
#  DenseVector([-5.8771, 0.1747, 0.0784]),
#  DenseVector([-4.3914, 0.2907, -0.1526]),
#  DenseVector([-4.2146, -0.1672, -0.5927]),
#  DenseVector([-4.9654, 0.6486, 0.0948]),
#  DenseVector([-3.7065, -0.2797, -0.1179]),
#  DenseVector([-4.169, -0.2704, 0.1445]),
#  DenseVector([-5.6163, 0.1329, 0.5571]),
#  DenseVector([-4.8837, -0.1488, -0.6387]),
#  DenseVector([-4.806, -0.1699, 0.2302]),
#  DenseVector([-4.6913, 0.3004, -0.0828]),
#  DenseVector([-4.0041, 0.0546, -0.3274]),
#  DenseVector([-5.586, -0.0938, 0.1154]),
#  DenseVector([-4.63, 0.1482, 0.2286]),
#  DenseVector([-4.1965, 0.1022, 0.0887]),
#  DenseVector([-3.7934, -0.1272, 0.1118]),
#  DenseVector([-3.7698, -0.322, 0.1975]),
#  DenseVector([-3.6947, -0.9502, -0.1556]),
#  DenseVector([-2.9929, -0.1985, -0.2143]),
#  DenseVector([-5.3539, -0.415, 0.1411]),
#  DenseVector([-4.5894, -0.7764, 0.4594]),
#  DenseVector([-4.6708, 0.0401, 0.4]),
#  DenseVector([-6.6603, -0.7555, 0.1505]),
#  DenseVector([-4.4258, -0.0149, -0.181]),
#  DenseVector([-5.5634, -0.3014, -0.5177]),
#  DenseVector([-3.5482, -0.1984, 0.5386]),
#  DenseVector([-4.5132, -0.0956, -0.3292]),
#  DenseVector([-3.8013, 0.2478, 0.0044]),
#  DenseVector([-4.0534, -0.5806, -0.3312]),
#  DenseVector([-6.6383, 0.1558, 0.0161]),
#  DenseVector([-5.2023, -0.1329, -0.0393]),
#  DenseVector([-4.134, -0.2452, -0.4946]),
#  DenseVector([-5.2998, -0.6205, -0.1377]),
#  DenseVector([-5.0314, 0.0853, 0.0228]),
#  DenseVector([-1.6852, -0.1016, -0.0358]),
#  DenseVector([-4.9794, -0.0028, 0.2313]),
#  DenseVector([-6.0617, -0.3708, -0.0655]),
#  DenseVector([-3.949, -0.2314, -0.549]),
#  DenseVector([-5.37, -0.2221, -0.0699]),
#  DenseVector([-4.8437, -0.5233, 0.4894]),
#  DenseVector([-4.388, -0.3018, -0.1133]),
#  DenseVector([-4.3701, -0.8428, 0.3198]),
#  DenseVector([-6.8871, -0.3894, -0.3612]),
#  DenseVector([-6.6771, -0.5299, -0.4698]),
#  DenseVector([-5.1403, -0.062, 0.4779]),
#  DenseVector([-5.0199, -0.2337, 0.3451]),
#  DenseVector([-4.0677, -0.3929, 0.0796]),
#  DenseVector([-3.4847, -0.1532, 0.2147]),
#  DenseVector([-5.6306, -0.733, 0.1911]),
#  DenseVector([-5.1886, -0.2763, 0.1605]),
#  DenseVector([-5.28, -0.1804, 0.3382]),
#  DenseVector([-5.6551, -0.4578, -0.4284]),
#  DenseVector([-3.8631, 0.5229, -0.184]),
#  DenseVector([-6.6406, -0.1103, -0.0837]),
#  DenseVector([-6.3267, -0.5108, -0.3587]),
#  DenseVector([-6.089, -0.4905, 0.0658]),
#  DenseVector([-5.4937, -0.0229, -0.1736]),
#  DenseVector([-4.3814, -0.2318, -0.2247]),
#  DenseVector([-3.6886, -0.4192, -0.3766]),
#  DenseVector([-3.4873, -0.0391, 0.0001]),
#  DenseVector([-4.0887, -0.7834, 0.0397]),
#  DenseVector([-3.3821, -0.2928, -0.7417]),
#  DenseVector([-5.3597, -0.04, -0.1227]),
#  DenseVector([-5.3891, 0.0508, -0.5236]),
#  DenseVector([-2.7503, -0.3453, -0.3068]),
#  DenseVector([-3.7256, -0.2923, 0.1233]),
#  DenseVector([-5.9189, -0.4732, 0.2492]),
#  DenseVector([-4.3284, -0.0261, -0.4145]),
#  DenseVector([-5.6071, -0.393, 0.0496]),
#  DenseVector([-4.7787, -0.3757, -0.2208]),
#  DenseVector([-4.2341, -0.1888, 0.1957]),
#  DenseVector([-5.4483, 0.0968, -0.2909]),
#  DenseVector([-6.0701, -0.145, 0.0644]),
#  DenseVector([-4.9355, 0.0979, 0.462]),
#  DenseVector([-6.2808, -0.0642, -0.3876]),
#  DenseVector([-4.957, 0.2278, -0.277]),
#  DenseVector([-3.4164, 0.1457, -0.6803]),
#  DenseVector([-4.5867, -0.0818, -0.1644]),
#  DenseVector([-3.6934, -0.0456, -0.1846]),
#  DenseVector([-6.1545, -0.135, 0.371]),
#  DenseVector([-5.5836, -0.2245, 0.3409]),
#  DenseVector([-5.5, 0.0198, 0.0193]),
#  DenseVector([-5.6659, -0.65, 0.1835]),
#  DenseVector([-4.2695, 0.5209, -0.2891]),
#  DenseVector([-3.8606, -0.1372, -0.5357]),
#  DenseVector([-4.3989, -0.3252, -0.177]),
#  DenseVector([-5.2424, -0.7215, -0.2373]),
#  DenseVector([-4.111, -0.1692, -0.265]),
#  DenseVector([-3.4869, -0.1449, -0.0467]),
#  DenseVector([-4.6358, -0.4182, 0.2282]),
#  DenseVector([-2.1645, -0.3232, 0.6257]),
#  DenseVector([-4.058, 0.0952, -0.2949]),
#  DenseVector([-5.9511, -0.1762, -0.0326]),
#  DenseVector([-4.4198, -0.5254, 0.2061]),
#  ...]

# %% [markdown]
# Find 3 PVs using SVD

# %%
mat = RowMatrix(task4)
task4.cache()
svd = mat.computeSVD(3, computeU=True)
U = svd.U       # The U factor is a RowMatrix.
s = svd.s       # The singular values are stored in a local dense vector.
V = svd.V# The V factor is a local dense matrix.

# %%
print V
print U
print s

# %% [markdown]
# Data visualization

# %%
dataV = sc.parallelize(mat.multiply(V).rows.collect())
f1 = rddData.map(lambda x:x.split(';')[0]).collect()
zipped = sc.parallelize(zip(f1,dataV.collect()))

chinese = zipped.filter(lambda x: x[0] == 'chinese').map(lambda x:(0,x[1])).take(100)
greek = zipped.filter(lambda x: x[0] == 'greek').map(lambda x:(1,x[1])).take(100)
mexican = zipped.filter(lambda x: x[0] == 'mexican').map(lambda x:(2,x[1])).take(100)
indian = zipped.filter(lambda x: x[0] == 'indian').map(lambda x:(3,x[1])).take(100)

twopoints = chinese+greek
threepoints = chinese+greek+mexican
fourpoints = chinese+greek+mexican+indian

# %% [markdown]
# ### filter to 2 cuisines

# %%
from mpl_toolkits.mplot3d import Axes3D

color = ['r','b', 'g']
marker = ['o', 's', '<']
fig = plt.figure()
ax = Axes3D(fig, elev=-150, azim=110)
for i in twopoints:
    f = i[1]
    t = i[0]
    ax.scatter3D(f[0], f[1], f[2], c = color[t], marker = marker[t])  
plt.show()

# %% [markdown]
# ### filter to 3 cuisines

# %%
from mpl_toolkits.mplot3d import Axes3D

color = ['r','b', 'g']
marker = ['o', 's', '<']
fig = plt.figure()
ax = Axes3D(fig, elev=-150, azim=110)
for i in threepoints:
    f = i[1]
    t = i[0]
    ax.scatter3D(f[0], f[1], f[2], c = color[t], marker = marker[t])  
plt.show()

# %% [markdown]
# ### filter to 4 cuisines

# %%
from mpl_toolkits.mplot3d import Axes3D

color = ['r','b', 'g','y']
marker = ['o', 's', '<','o']
fig = plt.figure()
ax = Axes3D(fig, elev=-150, azim=110)
for i in fourpoints:
    f = i[1]
    t = i[0]
    ax.scatter3D(f[0], f[1], f[2], c = color[t], marker = marker[t])  
plt.show()

# %%
sc.stop()
